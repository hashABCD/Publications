# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\ABCD\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
rec=[{'Country': 'Australia', 'hdi': 0.935, 'life_ex': 82.4, 'gni_pc': 42261},
 {'Country': 'Germany',
  'hdi': 0.9159999999999999,
  'life_ex': 80.9,
  'gni_pc': 43919},
 {'Country': 'United States', 'hdi': 0.915, 'life_ex': 79.1, 'gni_pc': 52947},
 {'Country': 'Canada',
  'hdi': 0.9129999999999999,
  'life_ex': 82.0,
  'gni_pc': 42155},
 {'Country': 'United Kingdom', 'hdi': 0.907, 'life_ex': 80.7, 'gni_pc': 39267},
 {'Country': 'South Korea', 'hdi': 0.898, 'life_ex': 81.9, 'gni_pc': 33890},
 {'Country': 'Japan',
  'hdi': 0.8909999999999999,
  'life_ex': 83.5,
  'gni_pc': 36927},
 {'Country': 'France', 'hdi': 0.888, 'life_ex': 82.2, 'gni_pc': 38056},
 {'Country': 'Italy', 'hdi': 0.873, 'life_ex': 83.1, 'gni_pc': 33030},
 {'Country': 'Saudi Arabia',
  'hdi': 0.8370000000000001,
  'life_ex': 74.3,
  'gni_pc': 52821},
 {'Country': 'Argentina', 'hdi': 0.836, 'life_ex': 76.3, 'gni_pc': 22050},
 {'Country': 'Russia',
  'hdi': 0.7979999999999999,
  'life_ex': 70.1,
  'gni_pc': 22352},
 {'Country': 'Turkey',
  'hdi': 0.7609999999999999,
  'life_ex': 75.3,
  'gni_pc': 18677},
 {'Country': 'Mexico',
  'hdi': 0.7559999999999999,
  'life_ex': 76.8,
  'gni_pc': 16056},
 {'Country': 'Brazil', 'hdi': 0.755, 'life_ex': 74.5, 'gni_pc': 15175},
 {'Country': 'China', 'hdi': 0.727, 'life_ex': 75.8, 'gni_pc': 12547},
 {'Country': 'Indonesia', 'hdi': 0.684, 'life_ex': 68.9, 'gni_pc': 9788},
 {'Country': 'South Africa',
  'hdi': 0.6659999999999999,
  'life_ex': 57.4,
  'gni_pc': 12122},
 {'Country': 'India', 'hdi': 0.609, 'life_ex': 68.0, 'gni_pc': 5497}]

# %%
hdi_df=pd.DataFrame(rec)
hdi_df.head()
# Out:
#           Country    hdi  life_ex  gni_pc
# 0       Australia  0.935     82.4   42261
# 1         Germany  0.916     80.9   43919
# 2   United States  0.915     79.1   52947
# 3          Canada  0.913     82.0   42155
# 4  United Kingdom  0.907     80.7   39267

# %%
abbr={'hdi':'Human Development Index (HDI)',
      'life_ex':'Life Expectancy at Birth',
      'gni_pc':'Gross National Income (GNI) per Capita'}

# %%
plt.style.use('ggplot')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=hdi_df, x='gni_pc', y='life_ex')

plt.title(f"G 20 Countries : {abbr['gni_pc']} vs {abbr['life_ex']}")
plt.xlabel(abbr['gni_pc'])
plt.ylabel(abbr['life_ex'])
          
for i in range(hdi_df.shape[0]):
          plt.text(hdi_df.gni_pc[i], y=hdi_df.life_ex[i], s=hdi_df.Country[i], alpha=0.8)
plt.savefig('blog_1.png')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=hdi_df, x='gni_pc', y='life_ex')

#Title and labels
plt.title(f"G 20 Countries : {abbr['gni_pc']} vs {abbr['life_ex']}")
plt.xlabel(abbr['gni_pc'])
plt.ylabel(abbr['life_ex'])

#Country names
for i in range(hdi_df.shape[0]):
          plt.text(hdi_df.gni_pc[i], y=hdi_df.life_ex[i], s=hdi_df.Country[i], alpha=0.8)

#Quadrant Marker          
plt.text(x=40000, y=68, s="Q4",alpha=0.7,fontsize=14, color='b')
plt.text(x=15000, y=68, s="Q3",alpha=0.7,fontsize=14, color='b')
plt.text(x=15000, y=78, s="Q2", alpha=0.7,fontsize=14, color='b')
plt.text(x=40000, y=78, s="Q1", alpha=0.7,fontsize=14, color='b')          

#Mean values          
plt.axhline(y=hdi_df.life_ex.mean(), color='k', linestyle='--', linewidth=1)           
plt.axvline(x=hdi_df.gni_pc.mean(), color='k',linestyle='--', linewidth=1) 
          
plt.savefig('blog_2.png')
plt.show()
