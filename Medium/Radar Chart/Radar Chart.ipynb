# %% [markdown]
# This is the notebook for [Medium Turorial on How to Generate a Radar Chart using Python](https://towardsdatascience.com/convert-photo-into-pixel-art-using-python-d0b9bd235797)

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %% [markdown]
# ### Data for visualization

# %%
subjects=['PHY','CHEM','BIO','MATH', 'ECO']
alice=[60,40,68,94,27]
bob=[81,30,75,37,46]

# %% [markdown]
# ### Obtain Angles

# %%
angles=np.linspace(0,2*np.pi,len(subjects), endpoint=False)
print(angles)
# Out:
# [0.         1.25663706 2.51327412 3.76991118 5.02654825]

# %% [markdown]
# ### Completing full circle

# %%
angles=np.concatenate((angles,[angles[0]]))
subjects.append(subjects[0])
alice.append(alice[0])
bob.append(bob[0])

# %% [markdown]
# ### Basic Chart

# %%
fig=plt.figure(figsize=(6,6))
ax=fig.add_subplot(polar=True)
ax.plot(angles,alice)
plt.show()

# %% [markdown]
# ### Customized Chart

# %%
fig=plt.figure(figsize=(6,6))
ax=fig.add_subplot(polar=True)
#basic plot
ax.plot(angles,alice, 'o--', color='g', label='Alice')
#fill plot
ax.fill(angles, alice, alpha=0.25, color='g')
#Add labels
ax.set_thetagrids(angles * 180/np.pi, subjects)
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# ### Alice vs Bob

# %%
fig=plt.figure(figsize=(6,6))
ax=fig.add_subplot(111, polar=True)
#Alice Plot
ax.plot(angles,alice, 'o-', color='g', linewidth=1, label='Alice')
ax.fill(angles, alice, alpha=0.25, color='g')
#Bob Plot
ax.plot(angles,bob, 'o-', color='orange', linewidth=1, label='Bob')
ax.fill(angles, bob, alpha=0.25, color='orange')
ax.set_thetagrids(angles * 180/np.pi, subjects)
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()
