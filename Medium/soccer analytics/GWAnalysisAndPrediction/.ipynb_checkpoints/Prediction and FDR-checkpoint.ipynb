# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import dataframe_image as dfi

import requests
from bs4 import BeautifulSoup

from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# %%
team_abb={'Everton':'EVE', 'Aston Villa':'AVL',
          'Leicester City':'LEI', 'Arsenal':'ARS',
          'Liverpool':'LIV','Tottenham':'TOT', 
          'Chelsea':'CHE', 'Leeds United':'LEE', 
          'Newcastle Utd':'NEW','West Ham':'WHU', 
          'Southampton':'SOU', 'Crystal Palace':'CRY', 
          'Wolves':'WOL','Manchester City':'MCI', 
          'Brighton':'BHA', 'Manchester Utd':'MUN', 
          'Watford':'WAT','Burnley':'BUR', 
          'Brentford':'BRE', 'Norwich City':'NOR'}

# %%
#To be executed once for gameweek
"""
url='https://fbref.com/en/comps/9/schedule/Premier-League-Scores-and-Fixtures'
r=requests.get(url)

soup=BeautifulSoup(r.text, 'html.parser')
table=soup.find('table')
rows=table.find_all('tr')

headers=['GW',
 'Day',
 'Date',
 'Time',
 'Home',
 'xG_Home',
 'Score',
 'xG_Away',
 'Away',
 'Attendance',
 'Venue',
 'Referee',
 'Match Report',
 'Notes']

data=[]
for row in rows[1:]:
    if row.find('th').text !='':
        temp=[]
        temp.append(int(row.find('th').text))
        temp.extend([x.text for x in row.find_all('td')])
        data.append(temp)

df=pd.DataFrame(data, columns=headers)
df=df[['GW', 'Date','Home', 'Away', 'xG_Home', 'xG_Away', 'Score']]

def score_splitter(x,h='h'):
    if x=='':
        return 0
    else:
        if h=='h':
            return int(x.split('–')[0])
        else:
            return int(x.split('–')[1])

df["G_Home"]=df.Score.apply(lambda x: score_splitter(x))
df["G_Away"]=df.Score.apply(lambda x: score_splitter(x, h='a'))

df.Home=df.Home.apply(lambda x:team_abb[x])
df.Away=df.Away.apply(lambda x:team_abb[x])
df.drop(['Score','Date'], axis=1, inplace=True)
df.to_csv('xg_data.csv', index=None)
df.head()

"""
# Out:
#    GW Home Away xG_Home xG_Away  G_Home  G_Away
# 0   1  BRE  ARS     1.3     1.5       2       0
# 1   1  MUN  LEE     1.5     0.6       5       1
# 2   1  LEI  WOL     0.8     1.1       1       0
# 3   1  BUR  BHA     1.0     1.3       1       2
# 4   1  WAT  AVL     1.2     1.1       3       2

# %%
df=pd.read_csv('xg_data.csv')
df.head()
# Out:
#    GW Home Away  xG_Home  xG_Away  G_Home  G_Away
# 0   1  BRE  ARS      1.3      1.5       2       0
# 1   1  MUN  LEE      1.5      0.6       5       1
# 2   1  LEI  WOL      0.8      1.1       1       0
# 3   1  BUR  BHA      1.0      1.3       1       2
# 4   1  WAT  AVL      1.2      1.1       3       2

# %%
def xG_converter(x):
    try:
        return float(x)
    except:
        return 0
df.xG_Away=df.xG_Away.apply(lambda x:xG_converter(x))
df.xG_Home=df.xG_Home.apply(lambda x:xG_converter(x))

# %%
df['GD']=df.G_Home-df.G_Away
df['Pts_Home']=df.GD.apply(lambda x : 3 if x>0 else (0 if x<0 else 1))
df['Pts_Away']=df.GD.apply(lambda x : 0 if x>0 else (3 if x<0 else 1))
df.head()
# Out:
#    GW Home Away  xG_Home  xG_Away  G_Home  G_Away  GD  Pts_Home  Pts_Away
# 0   1  BRE  ARS      1.3      1.5       2       0   2         3         0
# 1   1  MUN  LEE      1.5      0.6       5       1   4         3         0
# 2   1  LEI  WOL      0.8      1.1       1       0   1         3         0
# 3   1  BUR  BHA      1.0      1.3       1       2  -1         0         3
# 4   1  WAT  AVL      1.2      1.1       3       2   1         3         0

# %%
gw_last=6
gw_next=gw_last+1

# %%
df_temp=pd.DataFrame({'Team':list(team_abb.values())})
df_temp['M_h']=df_temp.Team\
.apply(lambda x:df[df.Home==x][df.GW<gw_next].count()[0])

df_temp['M_a']=df_temp.Team\
.apply(lambda x:df[df.Away==x][df.GW<gw_next].count()[0])

df_temp['M']=df_temp.M_h+df_temp.M_a

df_temp['W_h']=df_temp.Team\
.apply(lambda x:(df[df.Home==x][df.GW<gw_next].GD>0).sum())

df_temp['D_h']=df_temp.Team\
.apply(lambda x:(df[df.Home==x][df.GW<gw_next].GD==0).sum())

df_temp['L_h']=df_temp.Team\
.apply(lambda x:(df[df.Home==x][df.GW<gw_next].GD<0).sum())

df_temp['W_a']=df_temp.Team\
.apply(lambda x:(df[df.Away==x][df.GW<gw_next].GD<0).sum())

df_temp['D_a']=df_temp.Team\
.apply(lambda x:(df[df.Away==x][df.GW<gw_next].GD==0).sum())

df_temp['L_a']=df_temp.Team\
.apply(lambda x:(df[df.Away==x][df.GW<gw_next].GD>0).sum())

df_temp['W']=df_temp.W_h+df_temp.W_a
df_temp['L']=df_temp.L_h+df_temp.L_a
df_temp['D']=df_temp.D_h+df_temp.D_a

df_temp['xG_h']=df_temp.Team\
.apply(lambda x:df.xG_Home[df.Home==x][df.GW<gw_next].sum())

df_temp['xG_a']=df_temp.Team\
.apply(lambda x:df.xG_Away[df.Away==x][df.GW<gw_next].sum())

df_temp['xG']=df_temp.xG_a+df_temp.xG_h

df_temp['xGpm_h']=df_temp.xG_h/df_temp.M_h
df_temp['xGpm_a']=df_temp.xG_a/df_temp.M_a
df_temp['xGpm']=df_temp.xG/df_temp.M

df_temp['xGA_h']=df_temp.Team\
.apply(lambda x:df.xG_Away[df.Home==x][df.GW<gw_next].sum())

df_temp['xGA_a']=df_temp.Team\
.apply(lambda x:df.xG_Home[df.Away==x][df.GW<gw_next].sum())

df_temp['xGA']=df_temp.xGA_a+df_temp.xGA_h

df_temp['xGApm_h']=df_temp.xGA_h/df_temp.M_h
df_temp['xGApm_a']=df_temp.xGA_a/df_temp.M_a
df_temp['xGApm']=df_temp.xGA/df_temp.M

df_temp['delta_xGpm']=df_temp.xGpm-df_temp.xGApm


df_temp['P_h']=df_temp.Team\
.apply(lambda x:df.Pts_Home[df.Home==x][df.GW<gw_next].sum())

df_temp['P_a']=df_temp.Team\
.apply(lambda x:df.Pts_Away[df.Away==x][df.GW<gw_next].sum())

df_temp['P']=df_temp.P_a+df_temp.P_h

df_temp['Ppm_h']=df_temp.P_h/df_temp.M_h
df_temp['Ppm_a']=df_temp.P_a/df_temp.M_a
df_temp['Ppm']=df_temp.P/df_temp.M

df_temp['G_h']=df_temp.Team\
.apply(lambda x:df.G_Home[df.Home==x][df.GW<gw_next].sum())

df_temp['G_a']=df_temp.Team\
.apply(lambda x:df.G_Away[df.Away==x][df.GW<gw_next].sum())

df_temp['G']=df_temp.G_a+df_temp.G_h

df_temp['GA_h']=df_temp.Team\
.apply(lambda x:df.G_Away[df.Home==x][df.GW<gw_next].sum())

df_temp['GA_a']=df_temp.Team\
.apply(lambda x:df.G_Home[df.Away==x][df.GW<gw_next].sum())

df_temp['GA']=df_temp.GA_a+df_temp.GA_h

df_temp['GD']=df_temp.G-df_temp.GA

# %%
def predict_xg(df_fix):
    df_fix['G_home']=0.0
    df_fix['G_away']=0.0

    for i in range(df_fix.shape[0]):
        df_fix.G_home[i]=(df_temp.xGpm[df_temp.Team==df_fix.Home[i]].sum()+
                       df_temp.xGApm[df_temp.Team==df_fix.Away[i]].sum())/2
        df_fix.G_away[i]=(df_temp.xGpm[df_temp.Team==df_fix.Away[i]].sum()+
                       df_temp.xGApm[df_temp.Team==df_fix.Home[i]].sum())/2

    df_fix['GD']=df_fix['G_home']-df_fix['G_away']
    df_fix['GS']=df_fix['G_home']+df_fix['G_away']
    df_fix=df_fix.sort_values(by='GD', ascending=False)
    return df_fix

df_fix=df[df.GW>gw_last].iloc[:,:3].reset_index()
df_fix=predict_xg(df_fix)

df_fix['Match']=df_fix.Home+" Vs "+df_fix.Away


#df_result=pd.read_csv("xg_data.csv")
df_result=df
df_result=df_result[df_result.GW==gw_next]

#Name Preprocess
#df_result.Home=df_result.Home.apply(lambda x: team_abb[x])
#df_result.Away=df_result.Away.apply(lambda x: team_abb[x])

df_result['Match']=df_result.Home+" Vs "+df_result.Away
df_result["act_GD"]=df_result.G_Home-df_result.G_Away
df_result["act_xGD"]=df_result.xG_Home-df_result.xG_Away

df_result["pred_xG_Home"]=df_result.Match\
.apply(lambda x:df_fix.G_home[df_fix.Match==x][df_fix.GW==gw_next].sum())

df_result["pred_xG_Away"]=df_result.Match\
.apply(lambda x:df_fix.G_away[df_fix.Match==x][df_fix.GW==gw_next].sum())

df_result["pred_xGD"]=df_result.Match\
.apply(lambda x:df_fix.GD[df_fix.Match==x][df_fix.GW==gw_next].sum())

df_result['xG_diff']=abs(df_result.pred_xGD-df_result.act_xGD)
df_result['abs_pred_xGD']=abs(df_result.pred_xGD)
df_result.sort_values(by='xG_diff', ascending=True, inplace=True)
#df_result

# %%
plt.style.use('default')
plt.figure(figsize=(8,4))
plt.title("Predicted xG difference vs Actual xG difference")
sns.barplot(y='Match', x='pred_xGD', orient='h',data=df_result, color='red', alpha=0.8
            , label="Predicted")
sns.barplot(y='Match', x='act_xGD', orient='h', data=df_result, color='blue', alpha=0.8
            , label="Actual")
plt.xlabel("Expected Goal Difference")
#plt.xticks(rotation=90)
plt.legend(loc="upper right")
plt.grid(axis='x')
plt.savefig('pred_vs_act_prev.png')
plt.show()

# %%
gw_last=gw_last+1
gw_next=gw_last+1

# %%
df_temp=pd.DataFrame({'Team':list(team_abb.values())})
df_temp['M_h']=df_temp.Team\
.apply(lambda x:df[df.Home==x][df.GW<gw_next].count()[0])

df_temp['M_a']=df_temp.Team\
.apply(lambda x:df[df.Away==x][df.GW<gw_next].count()[0])

df_temp['M']=df_temp.M_h+df_temp.M_a

df_temp['W_h']=df_temp.Team\
.apply(lambda x:(df[df.Home==x][df.GW<gw_next].GD>0).sum())

df_temp['D_h']=df_temp.Team\
.apply(lambda x:(df[df.Home==x][df.GW<gw_next].GD==0).sum())

df_temp['L_h']=df_temp.Team\
.apply(lambda x:(df[df.Home==x][df.GW<gw_next].GD<0).sum())

df_temp['W_a']=df_temp.Team\
.apply(lambda x:(df[df.Away==x][df.GW<gw_next].GD<0).sum())

df_temp['D_a']=df_temp.Team\
.apply(lambda x:(df[df.Away==x][df.GW<gw_next].GD==0).sum())

df_temp['L_a']=df_temp.Team\
.apply(lambda x:(df[df.Away==x][df.GW<gw_next].GD>0).sum())

df_temp['W']=df_temp.W_h+df_temp.W_a
df_temp['L']=df_temp.L_h+df_temp.L_a
df_temp['D']=df_temp.D_h+df_temp.D_a

df_temp['xG_h']=df_temp.Team\
.apply(lambda x:df.xG_Home[df.Home==x][df.GW<gw_next].sum())

df_temp['xG_a']=df_temp.Team\
.apply(lambda x:df.xG_Away[df.Away==x][df.GW<gw_next].sum())

df_temp['xG']=df_temp.xG_a+df_temp.xG_h

df_temp['xGpm_h']=df_temp.xG_h/df_temp.M_h
df_temp['xGpm_a']=df_temp.xG_a/df_temp.M_a
df_temp['xGpm']=df_temp.xG/df_temp.M

df_temp['xGA_h']=df_temp.Team\
.apply(lambda x:df.xG_Away[df.Home==x][df.GW<gw_next].sum())

df_temp['xGA_a']=df_temp.Team\
.apply(lambda x:df.xG_Home[df.Away==x][df.GW<gw_next].sum())

df_temp['xGA']=df_temp.xGA_a+df_temp.xGA_h

df_temp['xGApm_h']=df_temp.xGA_h/df_temp.M_h
df_temp['xGApm_a']=df_temp.xGA_a/df_temp.M_a
df_temp['xGApm']=df_temp.xGA/df_temp.M

df_temp['delta_xGpm']=df_temp.xGpm-df_temp.xGApm


df_temp['P_h']=df_temp.Team\
.apply(lambda x:df.Pts_Home[df.Home==x][df.GW<gw_next].sum())

df_temp['P_a']=df_temp.Team\
.apply(lambda x:df.Pts_Away[df.Away==x][df.GW<gw_next].sum())

df_temp['P']=df_temp.P_a+df_temp.P_h

df_temp['Ppm_h']=df_temp.P_h/df_temp.M_h
df_temp['Ppm_a']=df_temp.P_a/df_temp.M_a
df_temp['Ppm']=df_temp.P/df_temp.M

df_temp['G_h']=df_temp.Team\
.apply(lambda x:df.G_Home[df.Home==x][df.GW<gw_next].sum())

df_temp['G_a']=df_temp.Team\
.apply(lambda x:df.G_Away[df.Away==x][df.GW<gw_next].sum())

df_temp['G']=df_temp.G_a+df_temp.G_h

df_temp['GA_h']=df_temp.Team\
.apply(lambda x:df.G_Away[df.Home==x][df.GW<gw_next].sum())

df_temp['GA_a']=df_temp.Team\
.apply(lambda x:df.G_Home[df.Away==x][df.GW<gw_next].sum())

df_temp['GA']=df_temp.GA_a+df_temp.GA_h

df_temp['GD']=df_temp.G-df_temp.GA_a

# %%
live_tbl=df_temp[['Team','M','W','D','L','P','GD','G','GA' ]].sort_values(by=['P','GD'], ascending=False)\
.style.background_gradient(cmap='RdYlGn',subset=['GD','G','GA']).hide_index()
dfi.export(live_tbl,"live_tbl.png")
live_tbl
# Out:
# <style  type="text/css" >
#     #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow0_col6 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow0_col7 {
#             background-color:  #33a456;
#             color:  #000000;
#             background-color:  #33a456;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow0_col8 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow1_col6 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow1_col7 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow1_col8 {
#             background-color:  #f7814c;
#             color:  #000000;
#             background-color:  #f7814c;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow2_col6 {
#             background-color:  #199750;
#             color:  #000000;
#             background-color:  #199750;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow2_col7 {
#             background-color:  #66bd63;
#             color:  #000000;
#             background-color:  #66bd63;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow2_col8 {
#             background-color:  #f7814c;
#             color:  #000000;
#             background-color:  #f7814c;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow3_col6 {
#             background-color:  #3faa59;
#             color:  #000000;
#             background-color:  #3faa59;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow3_col7 {
#             background-color:  #66bd63;
#             color:  #000000;
#             background-color:  #66bd63;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow3_col8 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow4_col6 {
#             background-color:  #bfe47a;
#             color:  #000000;
#             background-color:  #bfe47a;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow4_col7 {
#             background-color:  #91d068;
#             color:  #000000;
#             background-color:  #91d068;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow4_col8 {
#             background-color:  #fed884;
#             color:  #000000;
#             background-color:  #fed884;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow5_col6 {
#             background-color:  #d9ef8b;
#             color:  #000000;
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow5_col7 {
#             background-color:  #fee08b;
#             color:  #000000;
#             background-color:  #fee08b;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow5_col8 {
#             background-color:  #e65036;
#             color:  #000000;
#             background-color:  #e65036;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow6_col6 {
#             background-color:  #a5d86a;
#             color:  #000000;
#             background-color:  #a5d86a;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow6_col7 {
#             background-color:  #f2faae;
#             color:  #000000;
#             background-color:  #f2faae;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow6_col8 {
#             background-color:  #f7814c;
#             color:  #000000;
#             background-color:  #f7814c;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow7_col6 {
#             background-color:  #fdad60;
#             color:  #000000;
#             background-color:  #fdad60;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow7_col7 {
#             background-color:  #fa9857;
#             color:  #000000;
#             background-color:  #fa9857;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow7_col8 {
#             background-color:  #f1f9ac;
#             color:  #000000;
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow8_col6 {
#             background-color:  #3faa59;
#             color:  #000000;
#             background-color:  #3faa59;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow8_col7 {
#             background-color:  #66bd63;
#             color:  #000000;
#             background-color:  #66bd63;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow8_col8 {
#             background-color:  #f1f9ac;
#             color:  #000000;
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow9_col6 {
#             background-color:  #fee08b;
#             color:  #000000;
#             background-color:  #fee08b;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow9_col7 {
#             background-color:  #f2faae;
#             color:  #000000;
#             background-color:  #f2faae;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow9_col8 {
#             background-color:  #fff3ac;
#             color:  #000000;
#             background-color:  #fff3ac;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow10_col6 {
#             background-color:  #f46d43;
#             color:  #000000;
#             background-color:  #f46d43;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow10_col7 {
#             background-color:  #f46d43;
#             color:  #000000;
#             background-color:  #f46d43;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow10_col8 {
#             background-color:  #f1f9ac;
#             color:  #000000;
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow11_col6 {
#             background-color:  #feffbe;
#             color:  #000000;
#             background-color:  #feffbe;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow11_col7 {
#             background-color:  #f46d43;
#             color:  #000000;
#             background-color:  #f46d43;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow11_col8 {
#             background-color:  #f7814c;
#             color:  #000000;
#             background-color:  #f7814c;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow12_col6 {
#             background-color:  #fdad60;
#             color:  #000000;
#             background-color:  #fdad60;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow12_col7 {
#             background-color:  #fff5ae;
#             color:  #000000;
#             background-color:  #fff5ae;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow12_col8 {
#             background-color:  #a9da6c;
#             color:  #000000;
#             background-color:  #a9da6c;
#             color:  #000000;
#         }    #T_7134aa64_2c4a_11ec_8f88_8091337dc8dcrow13_col6 {
#             background-color:

# %%
df_fix=df[df.GW>gw_last].iloc[:,:3].reset_index()

def predict_xg(df_fix):
    df_fix['G_home']=0.0
    df_fix['G_away']=0.0

    for i in range(df_fix.shape[0]):
        df_fix.G_home[i]=(df_temp.xGpm[df_temp.Team==df_fix.Home[i]].sum()+
                       df_temp.xGApm[df_temp.Team==df_fix.Away[i]].sum())/2
        df_fix.G_away[i]=(df_temp.xGpm[df_temp.Team==df_fix.Away[i]].sum()+
                       df_temp.xGApm[df_temp.Team==df_fix.Home[i]].sum())/2

    df_fix['GD']=df_fix['G_home']-df_fix['G_away']
    df_fix['GS']=df_fix['G_home']+df_fix['G_away']
    df_fix=df_fix.sort_values(by='GD', ascending=False)
    return df_fix

df_fix=predict_xg(df_fix)

df_styled=df_fix.iloc[:,1:][df_fix.GW==gw_next].style.background_gradient(cmap='RdYlGn',subset=['GD','GS']).hide_index()
dfi.export(df_styled,"nxt_week.png")
df_styled
# Out:
# <style  type="text/css" >
#     #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow0_col5 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow0_col6 {
#             background-color:  #fff5ae;
#             color:  #000000;
#             background-color:  #fff5ae;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow1_col5 {
#             background-color:  #f7fcb4;
#             color:  #000000;
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow1_col6 {
#             background-color:  #fdfebc;
#             color:  #000000;
#             background-color:  #fdfebc;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow2_col5 {
#             background-color:  #fffab6;
#             color:  #000000;
#             background-color:  #fffab6;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow2_col6 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow3_col5 {
#             background-color:  #fff7b2;
#             color:  #000000;
#             background-color:  #fff7b2;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow3_col6 {
#             background-color:  #feeb9d;
#             color:  #000000;
#             background-color:  #feeb9d;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow4_col5 {
#             background-color:  #feea9b;
#             color:  #000000;
#             background-color:  #feea9b;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow4_col6 {
#             background-color:  #cdea83;
#             color:  #000000;
#             background-color:  #cdea83;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow5_col5 {
#             background-color:  #fee491;
#             color:  #000000;
#             background-color:  #fee491;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow5_col6 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow6_col5 {
#             background-color:  #fdc776;
#             color:  #000000;
#             background-color:  #fdc776;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow6_col6 {
#             background-color:  #f98e52;
#             color:  #000000;
#             background-color:  #f98e52;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow7_col5 {
#             background-color:  #fdc171;
#             color:  #000000;
#             background-color:  #fdc171;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow7_col6 {
#             background-color:  #b9e176;
#             color:  #000000;
#             background-color:  #b9e176;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow8_col5 {
#             background-color:  #f67f4b;
#             color:  #000000;
#             background-color:  #f67f4b;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow8_col6 {
#             background-color:  #f26841;
#             color:  #000000;
#             background-color:  #f26841;
#             color:  #000000;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow9_col5 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow9_col6 {
#             background-color:  #07753e;
#             color:  #f1f1f1;
#             background-color:  #07753e;
#             color:  #f1f1f1;
#         }</style><table id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dc" ><thead>    <tr>        <th class="col_heading level0 col0" >GW</th>        <th class="col_heading level0 col1" >Home</th>        <th class="col_heading level0 col2" >Away</th>        <th class="col_heading level0 col3" >G_home</th>        <th class="col_heading level0 col4" >G_away</th>        <th class="col_heading level0 col5" >GD</th>        <th class="col_heading level0 col6" >GS</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow0_col0" class="data row0 col0" >8</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow0_col1" class="data row0 col1" >MCI</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow0_col2" class="data row0 col2" >BUR</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow0_col3" class="data row0 col3" >1.87857</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow0_col4" class="data row0 col4" >0.814286</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow0_col5" class="data row0 col5" >1.06429</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow0_col6" class="data row0 col6" >2.69286</td>
#             </tr>
#             <tr>
#                                 <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow1_col0" class="data row1 col0" >8</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow1_col1" class="data row1 col1" >EVE</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow1_col2" class="data row1 col2" >WHU</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow1_col3" class="data row1 col3" >1.38571</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow1_col4" class="data row1 col4" >1.33571</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow1_col5" class="data row1 col5" >0.05</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow1_col6" class="data row1 col6" >2.72143</td>
#             </tr>
#             <tr>
#                                 <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow2_col0" class="data row2 col0" >8</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow2_col1" class="data row2 col1" >SOU</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow2_col2" class="data row2 col2" >LEE</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow2_col3" class="data row2 col3" >1.52857</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow2_col4" class="data row2 col4" >1.55714</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow2_col5" class="data row2 col5" >-0.0285714</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow2_col6" class="data row2 col6" >3.08571</td>
#             </tr>
#             <tr>
#                                 <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow3_col0" class="data row3 col0" >8</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow3_col1" class="data row3 col1" >BRE</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow3_col2" class="data row3 col2" >CHE</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow3_col3" class="data row3 col3" >1.31429</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow3_col4" class="data row3 col4" >1.35714</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow3_col5" class="data row3 col5" >-0.0428571</td>
#                         <td id="T_a1e46792_2c4a_11ec_b62d_8091337dc8dcrow3_col6" class="data row3 col6" >2.67143</td>
#             </tr>
#             <tr>

# %%
gw_dict={}
for i in range(1,7):
    gw_dict.update({str("GW"+str(gw_last+i)):gw_last+i})


df_fdr=pd.DataFrame({'Team':df_temp.Team})

for GW in gw_dict.keys():
    temp_df=df_fix[df_fix.GW==gw_dict[GW]]

    df_fdr[GW]=df_fdr.Team\
    .apply(lambda x:(temp_df[temp_df.Home==x].GD.sum()) 
           if x in (temp_df.Home.unique()) 
           else -temp_df[temp_df.Away==x].GD.sum())
    
sc=MinMaxScaler()
df_fdr['Mean']=df_fdr.mean(axis=1)
for col in gw_dict.keys():
    df_fdr[col]=sc.fit_transform(np.array(df_fdr[col]).reshape(-1,1))
df_fdr=df_fdr.sort_values(by='Mean', ascending=False)
df_fdr=df_fdr.style.background_gradient(cmap='RdYlGn',
                                 subset=list(gw_dict.keys()))
dfi.export(df_fdr,"fdr.png")
df_fdr
# Out:
# <style  type="text/css" >
#     #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow0_col1 {
#             background-color:  #016a38;
#             color:  #f1f1f1;
#             background-color:  #016a38;
#             color:  #f1f1f1;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow0_col2 {
#             background-color:  #60ba62;
#             color:  #000000;
#             background-color:  #60ba62;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow0_col3 {
#             background-color:  #0d8044;
#             color:  #f1f1f1;
#             background-color:  #0d8044;
#             color:  #f1f1f1;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow0_col4 {
#             background-color:  #5ab760;
#             color:  #000000;
#             background-color:  #5ab760;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow0_col5 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow0_col6 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow1_col1 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow1_col2 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow1_col3 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow1_col4 {
#             background-color:  #2aa054;
#             color:  #000000;
#             background-color:  #2aa054;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow1_col5 {
#             background-color:  #8ecf67;
#             color:  #000000;
#             background-color:  #8ecf67;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow1_col6 {
#             background-color:  #63bc62;
#             color:  #000000;
#             background-color:  #63bc62;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow2_col1 {
#             background-color:  #f7fcb4;
#             color:  #000000;
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow2_col2 {
#             background-color:  #026c39;
#             color:  #f1f1f1;
#             background-color:  #026c39;
#             color:  #f1f1f1;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow2_col3 {
#             background-color:  #51b35e;
#             color:  #000000;
#             background-color:  #51b35e;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow2_col4 {
#             background-color:  #54b45f;
#             color:  #000000;
#             background-color:  #54b45f;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow2_col5 {
#             background-color:  #bde379;
#             color:  #000000;
#             background-color:  #bde379;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow2_col6 {
#             background-color:  #fffdbc;
#             color:  #000000;
#             background-color:  #fffdbc;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow3_col1 {
#             background-color:  #fff8b4;
#             color:  #000000;
#             background-color:  #fff8b4;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow3_col2 {
#             background-color:  #b3df72;
#             color:  #000000;
#             background-color:  #b3df72;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow3_col3 {
#             background-color:  #7ac665;
#             color:  #000000;
#             background-color:  #7ac665;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow3_col4 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow3_col5 {
#             background-color:  #8ecf67;
#             color:  #000000;
#             background-color:  #8ecf67;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow3_col6 {
#             background-color:  #feea9b;
#             color:  #000000;
#             background-color:  #feea9b;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow4_col1 {
#             background-color:  #dff293;
#             color:  #000000;
#             background-color:  #dff293;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow4_col2 {
#             background-color:  #b7e075;
#             color:  #000000;
#             background-color:  #b7e075;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow4_col3 {
#             background-color:  #fedc88;
#             color:  #000000;
#             background-color:  #fedc88;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow4_col4 {
#             background-color:  #d9ef8b;
#             color:  #000000;
#             background-color:  #d9ef8b;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow4_col5 {
#             background-color:  #feec9f;
#             color:  #000000;
#             background-color:  #feec9f;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow4_col6 {
#             background-color:  #249d53;
#             color:  #000000;
#             background-color:  #249d53;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow5_col1 {
#             background-color:  #f5fbb2;
#             color:  #000000;
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow5_col2 {
#             background-color:  #279f53;
#             color:  #000000;
#             background-color:  #279f53;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow5_col3 {
#             background-color:  #d5ed88;
#             color:  #000000;
#             background-color:  #d5ed88;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow5_col4 {
#             background-color:  #54b45f;
#             color:  #000000;
#             background-color:  #54b45f;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow5_col5 {
#             background-color:  #fa9656;
#             color:  #000000;
#             background-color:  #fa9656;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow5_col6 {
#             background-color:  #e5f49b;
#             color:  #000000;
#             background-color:  #e5f49b;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow6_col1 {
#             background-color:  #bbe278;
#             color:  #000000;
#             background-color:  #bbe278;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow6_col2 {
#             background-color:  #f26841;
#             color:  #000000;
#             background-color:  #f26841;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow6_col3 {
#             background-color:  #84ca66;
#             color:  #000000;
#             background-color:  #84ca66;
#             color:  #000000;
#         }    #T_a2c03452_2c4a_11ec_b57b_8091337dc8dcrow6_col4 {
#             background-color:  #dd3d2d;

# %%
plt.figure(figsize=(8,5))
#plt.suptitle("EPL 2020/21 SEASON UPTO GW4")

plt.subplot(1,2,1)
plt.title("xG Scored per match")
sns.barplot(orient='h', x='xGpm',y='Team',
            data=df_temp.sort_values(by='xGpm',ascending=False))
plt.grid(which='both', axis='x')

plt.subplot(1,2,2)
plt.title("xG Conceaded per match")
sns.barplot(orient='h', x='xGApm',y='Team',
            data=df_temp.sort_values(by='xGApm',ascending=True))
plt.grid(which='both', axis='x')

plt.tight_layout()
plt.savefig('xg_xa.png')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.title("xG Scored Vs xG Conceded")
sns.scatterplot(data=df_temp, x='xGApm', y='xGpm')
for i in range(df_temp.shape[0]):
    plt.text(df_temp.xGApm[i]+0.01, df_temp.xGpm[i]+0.01, 
             df_temp.Team[i], fontdict={'fontsize':8})
plt.xlabel("xG conceded Per match")
plt.ylabel("xG Scored Per match")
#plt.plot([0,3],[0,3],'r--')
plt.xlim(df_temp.xGApm.min()-0.2,df_temp.xGApm.max()+0.2)
plt.ylim(df_temp.xGpm.min()-0.2,df_temp.xGpm.max()+0.2)
plt.axhline(y=df_temp.xGpm.mean(),ls='--', color='k')
plt.axvline(x=df_temp.xGApm.mean(),ls='--', color='k')

plt.text(x=1.6, y=2.25, s="Q1\nStrong Attack\nWeak Defence", 
         alpha=0.7,fontsize=9, color='red')
plt.text(x=0.9, y=2.25, s="Q2\nStrong Attack\nStrong Defence", 
         alpha=0.7,fontsize=9, color='red')
plt.text(x=0.9, y=0.9, s="Q3\nWeak Attack\nStrong Defence", 
         alpha=0.7,fontsize=9, color='red')
plt.text(x=1.6, y=0.9, s="Q3\nWeak Attack\nWeak Defence", 
         alpha=0.7,fontsize=9, color='red')

plt.savefig('scatter_xg_xa.png')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.title("xG Scored - xG Conceded")
sns.barplot(orient='h', x='delta_xGpm',y='Team', 
            data=df_temp.sort_values(by='delta_xGpm', ascending=False))
plt.grid(which='both', axis='x')
plt.xlabel('Delta xG')
plt.tight_layout()
plt.savefig('delta_xg.png')
plt.show()

# %%
data=df_temp.sort_values(by='delta_xGpm',ascending=False).reset_index()

y_max=round(max(data.xGpm.append(data.xGApm)),1)+0.2
y_min=round(min(data.xGpm.append(data.xGApm)),1)-0.2

plt.style.use('dark_background')
plt.figure(figsize=(10,6))

for i in range (data.shape[0]):
    if data.delta_xGpm[i]>0:
        c=str('green')
    else:
        c=str('red')
    plt.axvline(x=data.Team[i],ymax=(data.xGpm[i]-y_min)/(y_max-y_min),
                ymin=(data.xGApm[i]-y_min)/(y_max-y_min), color=c, linewidth=10, alpha=0.5, markersize=10)

sns.scatterplot(data=data,
               x='Team',y='xGpm', color='g', label='xG Scored')
sns.scatterplot(data=data,
               x='Team',y='xGApm',color='r', label='xG Conceded')
plt.ylim(y_min,y_max)
plt.ylabel('xG per game')
plt.grid(axis='y')
plt.savefig('xg-xapm.png')
plt.show()

# %%
df_fix['Match']=df_fix.Home+" Vs "+df_fix.Away


#df_result=pd.read_csv("xg_data.csv")
df_result=df
df_result=df_result[df_result.GW==gw_next]

#Name Preprocess
#df_result.Home=df_result.Home.apply(lambda x: team_abb[x])
#df_result.Away=df_result.Away.apply(lambda x: team_abb[x])

df_result['Match']=df_result.Home+" Vs "+df_result.Away
df_result["act_GD"]=df_result.G_Home-df_result.G_Away
df_result["act_xGD"]=df_result.xG_Home-df_result.xG_Away

df_result["pred_xG_Home"]=df_result.Match\
.apply(lambda x:df_fix.G_home[df_fix.Match==x][df_fix.GW==gw_next].sum())

df_result["pred_xG_Away"]=df_result.Match\
.apply(lambda x:df_fix.G_away[df_fix.Match==x][df_fix.GW==gw_next].sum())

df_result["pred_xGD"]=df_result.Match\
.apply(lambda x:df_fix.GD[df_fix.Match==x][df_fix.GW==gw_next].sum())

df_result['xG_diff']=abs(df_result.pred_xGD-df_result.act_xGD)
df_result['abs_pred_xGD']=abs(df_result.pred_xGD)
df_result.sort_values(by='abs_pred_xGD', ascending=False, inplace=True)
#df_result

# %%
plt.style.use('default')
plt.figure(figsize=(8,4))
plt.title("Predicted xG difference")
sns.barplot(y='Match', x='pred_xGD', orient='h',data=df_result, color='red', alpha=0.8
            , label="Predicted")
plt.xlabel("Expected Goal Difference")
plt.grid(axis='x')
plt.savefig('pred_vs_act.png')
plt.show()
